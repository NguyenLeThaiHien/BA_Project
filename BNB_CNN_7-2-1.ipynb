# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense

# %%
# Read dataset file
df = pd.read_csv('BNB.csv',sep=";")
df = df[['Price']]
df = df.dropna()
df
# Out:
#        Price
# 0      15.11
# 1      14.33
# 2      14.17
# 3      14.67
# 4      13.88
# ...      ...
# 1822  312.09
# 1823  313.40
# 1824  311.30
# 1825  314.29
# 1826  309.40
#
# [1827 rows x 1 columns]

# %%
# Split the data into training, testing, and validation sets with 7:2:1
train_size = int(0.7 * len(df))
test_size = int(0.2 * len(df))
val_size = len(df) - train_size - test_size

train_data = df[:train_size]
test_data = df[train_size:train_size+test_size]
val_data = df[train_size+test_size:]

# %%
 #Normalize the data
mean = train_data.mean()
meant = test_data.mean()
meanv = val_data.mean()
std = train_data.std()
stdt = test_data.std()
stdv = val_data.std()
train_data = (train_data - mean) / std
test_data = (test_data - meant) / stdt
val_data = (val_data - meanv) / stdv

# %%
# Prepare the data for CNN
window_size = 10

def create_sequences(data, window_size):
    X = []
    y = []
    for i in range(len(data) - window_size):
        X.append(data[i:i+window_size])
        y.append(data[i+window_size])
    return np.array(X), np.array(y)

X_train, y_train = create_sequences(train_data.values, window_size)
X_test, y_test = create_sequences(test_data.values, window_size)
X_val, y_val = create_sequences(val_data.values, window_size)

# %%
# Build the CNN model
model = Sequential()
model.add(Conv1D(filters=32, kernel_size=3, activation='relu', input_shape=(window_size, 1)))
model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dense(1))

model.compile(optimizer='adam', loss='mse')

# %%
# Train the model
model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_val, y_val))
# Out:
# Epoch 1/100
# 40/40 [==============================] - 2s 11ms/step - loss: 0.1948 - val_loss: 0.2811
# Epoch 2/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0341 - val_loss: 0.2863
# Epoch 3/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0258 - val_loss: 0.2713
# Epoch 4/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0230 - val_loss: 0.2438
# Epoch 5/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0191 - val_loss: 0.2422
# Epoch 6/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0171 - val_loss: 0.2242
# Epoch 7/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0145 - val_loss: 0.1960
# Epoch 8/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0136 - val_loss: 0.2000
# Epoch 9/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0126 - val_loss: 0.1965
# Epoch 10/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0115 - val_loss: 0.1788
# Epoch 11/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0121 - val_loss: 0.1697
# Epoch 12/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0116 - val_loss: 0.1820
# Epoch 13/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0099 - val_loss: 0.1589
# Epoch 14/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0097 - val_loss: 0.1652
# Epoch 15/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0091 - val_loss: 0.1526
# Epoch 16/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0089 - val_loss: 0.1540
# Epoch 17/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0090 - val_loss: 0.1544
# Epoch 18/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0080 - val_loss: 0.1442
# Epoch 19/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0088 - val_loss: 0.1574
# Epoch 20/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0102 - val_loss: 0.1530
# Epoch 21/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0079 - val_loss: 0.1456
# Epoch 22/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0083 - val_loss: 0.1487
# Epoch 23/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0087 - val_loss: 0.1430
# Epoch 24/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0080 - val_loss: 0.1418
# Epoch 25/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0076 - val_loss: 0.1368
# Epoch 26/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0078 - val_loss: 0.1351
# Epoch 27/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0088 - val_loss: 0.1493
# Epoch 28/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0071 - val_loss: 0.1385
# Epoch 29/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0076 - val_loss: 0.1444
# Epoch 30/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0073 - val_loss: 0.1367
# Epoch 31/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0067 - val_loss: 0.1423
# Epoch 32/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0068 - val_loss: 0.1353
# Epoch 33/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0074 - val_loss: 0.1295
# Epoch 34/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0068 - val_loss: 0.1258
# Epoch 35/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0079 - val_loss: 0.1372
# Epoch 36/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0074 - val_loss: 0.1305
# Epoch 37/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0070 - val_loss: 0.1278
# Epoch 38/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0062 - val_loss: 0.1324
# Epoch 39/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0064 - val_loss: 0.1258
# Epoch 40/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0062 - val_loss: 0.1248
# Epoch 41/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0065 - val_loss: 0.1268
# Epoch 42/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0071 - val_loss: 0.1251
# Epoch 43/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0071 - val_loss: 0.1235
# Epoch 44/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0067 - val_loss: 0.1244
# Epoch 45/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0069 - val_loss: 0.1236
# Epoch 46/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0067 - val_loss: 0.1328
# Epoch 47/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0062 - val_loss: 0.1351
# Epoch 48/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0081 - val_loss: 0.1251
# Epoch 49/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0062 - val_loss: 0.1331
# Epoch 50/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0059 - val_loss: 0.1308
# Epoch 51/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0065 - val_loss: 0.1357
# Epoch 52/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0071 - val_loss: 0.1346
# Epoch 53/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0075 - val_loss: 0.1452
# Epoch 54/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0063 - val_loss: 0.1297
# Epoch 55/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0062 - val_loss: 0.1329
# Epoch 56/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0058 - val_loss: 0.1370
# Epoch 57/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0068 - val_loss: 0.1336
# Epoch 58/100
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0059 - val_loss: 0.1370
# Epoch 59/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0063 - val_loss: 0.1409
# Epoch 60/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0059 - val_loss: 0.1453
# Epoch 61/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0065 - val_loss: 0.1530
# Epoch 62/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0064 - val_loss: 0.1415
# Epoch 63/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0060 - val_loss: 0.1553
# Epoch 64/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0067 - val_loss: 0.1473
# Epoch 65/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0057 - val_loss: 0.1492
# Epoch 66/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0055 - val_loss: 0.1460
# Epoch 67/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0056 - val_loss: 0.1392
# Epoch 68/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0066 - val_loss: 0.1514
# Epoch 69/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0061 - val_loss: 0.1562
# Epoch 70/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0061 - val_loss: 0.1584
# Epoch 71/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0080 - val_loss: 0.1599
# Epoch 72/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0062 - val_loss: 0.1614
# Epoch 73/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0057 - val_loss: 0.1497
# Epoch 74/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0058 - val_loss: 0.1581
# Epoch 75/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0057 - val_loss: 0.1631
# Epoch 76/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0057 - val_loss: 0.1531
# Epoch 77/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0064 - val_loss: 0.1592
# Epoch 78/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0061 - val_loss: 0.1639
# Epoch 79/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0060 - val_loss: 0.1733
# Epoch 80/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0059 - val_loss: 0.1748
# Epoch 81/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0057 - val_loss: 0.1713
# Epoch 82/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0055 - val_loss: 0.1708
# Epoch 83/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0062 - val_loss: 0.1645
# Epoch 84/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0056 - val_loss: 0.1859
# Epoch 85/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0057 - val_loss: 0.1723
# Epoch 86/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0063 - val_loss: 0.1774
# Epoch 87/100
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0067 - val_loss: 0.1935
# Epoch 88/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0060 - val_loss: 0.1912
# Epoch 89/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0062 - val_loss: 0.1956
# Epoch 90/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0056 - val_loss: 0.1773
# Epoch 91/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0052 - val_loss: 0.1938
# Epoch 92/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0052 - val_loss: 0.1955
# Epoch 93/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0054 - val_loss: 0.2260
# Epoch 94/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0057 - val_loss: 0.1919
# Epoch 95/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0054 - val_loss: 0.2035
# Epoch 96/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0056 - val_loss: 0.2073
# Epoch 97/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0052 - val_loss: 0.1927
# Epoch 98/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0066 - val_loss: 0.1947
# Epoch 99/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0059 - val_loss: 0.2134
# Epoch 100/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0073 - val_loss: 0.1924

# %%
# Make predictions
y_pred = model.predict(X_test)
# Inverse transform the predictions
y_pred = y_pred * pd.Series(stdt).values[0] + pd.Series(meant).values[0]
# Out:
# 12/12 [==============================] - 0s 3ms/step

# %%
# Make predictions
y_vpred = model.predict(X_val)
# Inverse transform the predictions
y_vpred = y_vpred * pd.Series(stdv).values[0] + pd.Series(meanv).values[0]
# Out:
# 6/6 [==============================] - 0s 3ms/step

# %%
train_size = int(0.7 * len(df))
test_size = int(0.2 * len(df))
val_size = len(df) - train_size - test_size

train_data = df[:train_size]
test_data = df[train_size:train_size+test_size]
val_data = df[train_size+test_size:]
# re make predictions on the testing set
x_test = np.array(test_data.index).reshape(-1, 1)
y_test = np.array(test_data['Price'])
# re make predictions on the validate set
x_val = np.array(val_data.index).reshape(-1, 1)
y_val = np.array(val_data['Price'])
train_data = df[:train_size]
test_data = df[train_size:train_size+test_size]
val_data = df[train_size+test_size:]
# calculate the RMSE
valid_rmse = np.sqrt(np.mean((y_vpred - y_val)**2))
test_rmse = np.sqrt(np.mean((y_pred - y_test)**2))
print('Validation RMSE:', valid_rmse)
print('Testing RMSE:', test_rmse)

# calculate the MAPE
valid_mape = np.mean(np.abs((y_val - y_vpred) / y_val)) * 100
test_mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100
print("Validation MAPE:", valid_mape)
print("Testing MAPE:", test_mape)

# calculate the MAE
valid_mae = np.mean(np.abs(y_vpred - y_val))
test_mae = np.mean(np.abs(y_pred - y_test))
print("Validation MAE:", valid_mae)
print("Testing MAE:", test_mae)
# Out:
# Validation RMSE: 38.30907172202934
# Testing RMSE: 145.21429687971658
# Validation MAPE: 10.325753079367562
# Testing MAPE: 32.80426334197086
# Validation MAE: 29.930211979276475
# Testing MAE: 114.71209137060632

# %%
# ploting the actual values and predicted values
plt.plot(test_data.index, test_data['Price'])
plt.plot(val_data.index, val_data['Price'])
plt.plot(test_data.index[-len(y_pred):], y_pred)
plt.plot(val_data.index[-len(y_vpred):], y_vpred)
plt.legend(['Test','Validate', 'Predictions_test','Predictions_validate'])
plt.show()
