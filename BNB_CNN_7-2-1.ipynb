# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense

# %%
# Read dataset file
df = pd.read_csv('BNB.csv',sep=";")
df = df[['Price']]
df = df.dropna()
df
# Out:
#        Price
# 0      15.11
# 1      14.33
# 2      14.17
# 3      14.67
# 4      13.88
# ...      ...
# 1822  312.09
# 1823  313.40
# 1824  311.30
# 1825  314.29
# 1826  309.40
#
# [1827 rows x 1 columns]

# %%
# Split the data into training, testing, and validation sets with 7:2:1
train_size = int(0.7 * len(df))
test_size = int(0.2 * len(df))
val_size = len(df) - train_size - test_size

train_data = df[:train_size]
test_data = df[train_size:train_size+test_size]
val_data = df[train_size+test_size:]

# %%
 #Normalize the data
mean = train_data.mean()
meant = test_data.mean()
meanv = val_data.mean()
std = train_data.std()
stdt = test_data.std()
stdv = val_data.std()
train_data = (train_data - mean) / std
test_data = (test_data - meant) / stdt
val_data = (val_data - meanv) / stdv

# %%
# Prepare the data for CNN
window_size = 10

def create_sequences(data, window_size):
    X = []
    y = []
    for i in range(len(data) - window_size):
        X.append(data[i:i+window_size])
        y.append(data[i+window_size])
    return np.array(X), np.array(y)

X_train, y_train = create_sequences(train_data.values, window_size)
X_test, y_test = create_sequences(test_data.values, window_size)
X_val, y_val = create_sequences(val_data.values, window_size)

# %%
# Build the CNN model
model = Sequential()
model.add(Conv1D(filters=32, kernel_size=3, activation='relu', input_shape=(window_size, 1)))
model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dense(1))

model.compile(optimizer='adam', loss='mse')

# %%
# Train the model
model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_val, y_val))
# Out:
# Epoch 1/100
# 40/40 [==============================] - 1s 7ms/step - loss: 0.1540 - val_loss: 0.3033
# Epoch 2/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0254 - val_loss: 0.2830
# Epoch 3/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0215 - val_loss: 0.2604
# Epoch 4/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0198 - val_loss: 0.2615
# Epoch 5/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0174 - val_loss: 0.2522
# Epoch 6/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0166 - val_loss: 0.2414
# Epoch 7/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0139 - val_loss: 0.2266
# Epoch 8/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0121 - val_loss: 0.2218
# Epoch 9/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0119 - val_loss: 0.2012
# Epoch 10/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0108 - val_loss: 0.2073
# Epoch 11/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0102 - val_loss: 0.1897
# Epoch 12/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0091 - val_loss: 0.1828
# Epoch 13/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0085 - val_loss: 0.1771
# Epoch 14/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0082 - val_loss: 0.1682
# Epoch 15/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0088 - val_loss: 0.1659
# Epoch 16/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0075 - val_loss: 0.1631
# Epoch 17/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0071 - val_loss: 0.1586
# Epoch 18/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0089 - val_loss: 0.1659
# Epoch 19/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0085 - val_loss: 0.1597
# Epoch 20/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0073 - val_loss: 0.1548
# Epoch 21/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0071 - val_loss: 0.1513
# Epoch 22/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0084 - val_loss: 0.1507
# Epoch 23/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0066 - val_loss: 0.1479
# Epoch 24/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0084 - val_loss: 0.1513
# Epoch 25/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0066 - val_loss: 0.1485
# Epoch 26/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0079 - val_loss: 0.1444
# Epoch 27/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0066 - val_loss: 0.1445
# Epoch 28/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0069 - val_loss: 0.1428
# Epoch 29/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0068 - val_loss: 0.1414
# Epoch 30/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0065 - val_loss: 0.1421
# Epoch 31/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0071 - val_loss: 0.1382
# Epoch 32/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0071 - val_loss: 0.1447
# Epoch 33/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0069 - val_loss: 0.1371
# Epoch 34/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0073 - val_loss: 0.1351
# Epoch 35/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0063 - val_loss: 0.1356
# Epoch 36/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0090 - val_loss: 0.1329
# Epoch 37/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0065 - val_loss: 0.1352
# Epoch 38/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0065 - val_loss: 0.1348
# Epoch 39/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0066 - val_loss: 0.1418
# Epoch 40/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0074 - val_loss: 0.1310
# Epoch 41/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0066 - val_loss: 0.1354
# Epoch 42/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0061 - val_loss: 0.1296
# Epoch 43/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0075 - val_loss: 0.1341
# Epoch 44/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0069 - val_loss: 0.1267
# Epoch 45/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0066 - val_loss: 0.1268
# Epoch 46/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0061 - val_loss: 0.1304
# Epoch 47/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0060 - val_loss: 0.1263
# Epoch 48/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0061 - val_loss: 0.1275
# Epoch 49/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0067 - val_loss: 0.1295
# Epoch 50/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0068 - val_loss: 0.1277
# Epoch 51/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0064 - val_loss: 0.1247
# Epoch 52/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0061 - val_loss: 0.1241
# Epoch 53/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0064 - val_loss: 0.1237
# Epoch 54/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0061 - val_loss: 0.1241
# Epoch 55/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0069 - val_loss: 0.1268
# Epoch 56/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0064 - val_loss: 0.1193
# Epoch 57/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0065 - val_loss: 0.1207
# Epoch 58/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0072 - val_loss: 0.1194
# Epoch 59/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0062 - val_loss: 0.1205
# Epoch 60/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0059 - val_loss: 0.1222
# Epoch 61/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0065 - val_loss: 0.1205
# Epoch 62/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0059 - val_loss: 0.1243
# Epoch 63/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0061 - val_loss: 0.1212
# Epoch 64/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0070 - val_loss: 0.1214
# Epoch 65/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0073 - val_loss: 0.1271
# Epoch 66/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0076 - val_loss: 0.1203
# Epoch 67/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0061 - val_loss: 0.1239
# Epoch 68/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0066 - val_loss: 0.1207
# Epoch 69/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0058 - val_loss: 0.1199
# Epoch 70/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0058 - val_loss: 0.1238
# Epoch 71/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0059 - val_loss: 0.1239
# Epoch 72/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0057 - val_loss: 0.1208
# Epoch 73/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0059 - val_loss: 0.1193
# Epoch 74/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0063 - val_loss: 0.1206
# Epoch 75/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0057 - val_loss: 0.1243
# Epoch 76/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0061 - val_loss: 0.1268
# Epoch 77/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0057 - val_loss: 0.1238
# Epoch 78/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0057 - val_loss: 0.1220
# Epoch 79/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0056 - val_loss: 0.1283
# Epoch 80/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0068 - val_loss: 0.1259
# Epoch 81/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0057 - val_loss: 0.1309
# Epoch 82/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0055 - val_loss: 0.1226
# Epoch 83/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0055 - val_loss: 0.1288
# Epoch 84/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0056 - val_loss: 0.1372
# Epoch 85/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0061 - val_loss: 0.1262
# Epoch 86/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0057 - val_loss: 0.1343
# Epoch 87/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0061 - val_loss: 0.1381
# Epoch 88/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0061 - val_loss: 0.1359
# Epoch 89/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0056 - val_loss: 0.1358
# Epoch 90/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0055 - val_loss: 0.1361
# Epoch 91/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0054 - val_loss: 0.1323
# Epoch 92/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0064 - val_loss: 0.1353
# Epoch 93/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0067 - val_loss: 0.1371
# Epoch 94/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0056 - val_loss: 0.1325
# Epoch 95/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0061 - val_loss: 0.1441
# Epoch 96/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0058 - val_loss: 0.1319
# Epoch 97/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0058 - val_loss: 0.1448
# Epoch 98/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0065 - val_loss: 0.1482
# Epoch 99/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0059 - val_loss: 0.1402
# Epoch 100/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0065 - val_loss: 0.1499

# %%
# Make predictions
y_pred = model.predict(X_test)
# Inverse transform the predictions
y_pred = y_pred * pd.Series(stdt).values[0] + pd.Series(meant).values[0]
# Out:
# 12/12 [==============================] - 0s 1ms/step

# %%
# Make predictions
y_vpred = model.predict(X_val)
# Inverse transform the predictions
y_vpred = y_vpred * pd.Series(stdv).values[0] + pd.Series(meanv).values[0]
# Out:
# 6/6 [==============================] - 0s 0s/step

# %%
train_size = int(0.7 * len(df))
test_size = int(0.2 * len(df))
val_size = len(df) - train_size - test_size

train_data = df[:train_size]
test_data = df[train_size:train_size+test_size]
val_data = df[train_size+test_size:]
# re make predictions on the testing set
x_test = np.array(test_data.index).reshape(-1, 1)
y_test = np.array(test_data['Price'])
# re make predictions on the validate set
x_val = np.array(val_data.index).reshape(-1, 1)
y_val = np.array(val_data['Price'])
train_data = df[:train_size]
test_data = df[train_size:train_size+test_size]
val_data = df[train_size+test_size:]
# calculate the RMSE
valid_rmse = np.sqrt(np.mean((y_vpred - y_val)**2))
test_rmse = np.sqrt(np.mean((y_pred - y_test)**2))
print('Validation RMSE:', valid_rmse)
print('Testing RMSE:', test_rmse)

# calculate the MAPE
valid_mape = np.mean(np.abs((y_val - y_vpred) / y_val)) * 100
test_mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100
print("Validation MAPE:", valid_mape)
print("Testing MAPE:", test_mape)

# calculate the MAE
valid_mae = np.mean(np.abs(y_vpred - y_val))
test_mae = np.mean(np.abs(y_pred - y_test))
print("Validation MAE:", valid_mae)
print("Testing MAPE:", test_mape)
# Out:
# Validation RMSE: 37.25332440360834
# Testing RMSE: 145.1575510637664
# Validation MAPE: 10.048681470101444
# Testing MAPE: 32.80019776104851
# Validation MAE: 28.99897455679661
# Testing MAPE: 32.80019776104851

# %%
# ploting the actual values and predicted values
plt.plot(test_data.index, test_data['Price'])
plt.plot(val_data.index, val_data['Price'])
plt.plot(test_data.index[-len(y_pred):], y_pred)
plt.plot(val_data.index[-len(y_vpred):], y_vpred)
plt.legend(['Test','Validate', 'Predictions_test','Predictions_validate'])
plt.show()
