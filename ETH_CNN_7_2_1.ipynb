# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense

# %%
# Read dataset file
df = pd.read_csv('/content/ETH.csv')
df = df[['Price']]
df = df.dropna()
df
# Out:
#         Price
# 0      693.28
# 1      696.76
# 2      716.02
# 3      696.85
# 4      642.17
# ...       ...
# 1822  1799.36
# 1823  1817.11
# 1824  1823.98
# 1825  1821.73
# 1826  1800.99
#
# [1827 rows x 1 columns]

# %%
# Split the data into training, testing, and validation sets
train_size = int(0.7 * len(df))
test_size = int(0.2 * len(df))
val_size = len(df) - train_size - test_size

train_data = df[:train_size]
test_data = df[train_size:train_size+test_size]
val_data = df[train_size+test_size:]

# %%
# Normalize the data
mean = train_data.mean()
meant = test_data.mean()
meanv = val_data.mean()
std = train_data.std()
stdt = test_data.std()
stdv = val_data.std()
train_data = (train_data - mean) / std
test_data = (test_data - meant) / stdt
val_data = (val_data - meanv) / stdv

# %%
# Prepare the data for CNN
window_size = 10

def create_sequences(data, window_size):
    X = []
    y = []
    for i in range(len(data) - window_size):
        X.append(data[i:i+window_size])
        y.append(data[i+window_size])
    return np.array(X), np.array(y)

X_train, y_train = create_sequences(train_data.values, window_size)
X_test, y_test = create_sequences(test_data.values, window_size)
X_val, y_val = create_sequences(val_data.values, window_size)

# %%
y_train
# Out:
# array([[-0.29271528],
#        [-0.24394726],
#        [-0.25184568],
#        ...,
#        [ 3.40363583],
#        [ 3.38662248],
#        [ 3.33061797]])

# %%
# Build the CNN model
model = Sequential()
model.add(Conv1D(filters=32, kernel_size=3, activation='relu', input_shape=(window_size, 1)))
model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dense(1))

model.compile(optimizer='adam', loss='mse')

# %%
# Train the model
model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_val, y_val))
# Out:
# Epoch 1/100
# 40/40 [==============================] - 10s 13ms/step - loss: 0.2498 - val_loss: 0.1074
# Epoch 2/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0181 - val_loss: 0.0924
# Epoch 3/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0159 - val_loss: 0.0896
# Epoch 4/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0138 - val_loss: 0.0800
# Epoch 5/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0118 - val_loss: 0.0736
# Epoch 6/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0103 - val_loss: 0.0774
# Epoch 7/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0111 - val_loss: 0.0724
# Epoch 8/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0092 - val_loss: 0.0692
# Epoch 9/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0095 - val_loss: 0.0695
# Epoch 10/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0090 - val_loss: 0.0591
# Epoch 11/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0080 - val_loss: 0.0578
# Epoch 12/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0088 - val_loss: 0.0566
# Epoch 13/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0075 - val_loss: 0.0585
# Epoch 14/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0077 - val_loss: 0.0504
# Epoch 15/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0084 - val_loss: 0.0541
# Epoch 16/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0082 - val_loss: 0.0566
# Epoch 17/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0076 - val_loss: 0.0492
# Epoch 18/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0069 - val_loss: 0.0553
# Epoch 19/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0079 - val_loss: 0.0473
# Epoch 20/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0069 - val_loss: 0.0500
# Epoch 21/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0067 - val_loss: 0.0475
# Epoch 22/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0062 - val_loss: 0.0451
# Epoch 23/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0062 - val_loss: 0.0453
# Epoch 24/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0060 - val_loss: 0.0458
# Epoch 25/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0065 - val_loss: 0.0433
# Epoch 26/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0063 - val_loss: 0.0427
# Epoch 27/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0060 - val_loss: 0.0424
# Epoch 28/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0060 - val_loss: 0.0444
# Epoch 29/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0067 - val_loss: 0.0413
# Epoch 30/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0055 - val_loss: 0.0402
# Epoch 31/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0059 - val_loss: 0.0419
# Epoch 32/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0058 - val_loss: 0.0393
# Epoch 33/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0059 - val_loss: 0.0403
# Epoch 34/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0059 - val_loss: 0.0413
# Epoch 35/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0057 - val_loss: 0.0382
# Epoch 36/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0064 - val_loss: 0.0379
# Epoch 37/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0067 - val_loss: 0.0375
# Epoch 38/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0061 - val_loss: 0.0392
# Epoch 39/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0056 - val_loss: 0.0379
# Epoch 40/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0054 - val_loss: 0.0387
# Epoch 41/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0053 - val_loss: 0.0405
# Epoch 42/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0058 - val_loss: 0.0379
# Epoch 43/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0053 - val_loss: 0.0394
# Epoch 44/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0051 - val_loss: 0.0384
# Epoch 45/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0059 - val_loss: 0.0363
# Epoch 46/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0057 - val_loss: 0.0378
# Epoch 47/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0057 - val_loss: 0.0367
# Epoch 48/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0055 - val_loss: 0.0374
# Epoch 49/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0063 - val_loss: 0.0365
# Epoch 50/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0081 - val_loss: 0.0369
# Epoch 51/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0056 - val_loss: 0.0403
# Epoch 52/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0055 - val_loss: 0.0373
# Epoch 53/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0056 - val_loss: 0.0371
# Epoch 54/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0053 - val_loss: 0.0367
# Epoch 55/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0052 - val_loss: 0.0359
# Epoch 56/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0054 - val_loss: 0.0353
# Epoch 57/100
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0056 - val_loss: 0.0387
# Epoch 58/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0054 - val_loss: 0.0371
# Epoch 59/100
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0049 - val_loss: 0.0364
# Epoch 60/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0053 - val_loss: 0.0377
# Epoch 61/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0075 - val_loss: 0.0361
# Epoch 62/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0056 - val_loss: 0.0353
# Epoch 63/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0063 - val_loss: 0.0369
# Epoch 64/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0053 - val_loss: 0.0367
# Epoch 65/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0050 - val_loss: 0.0353
# Epoch 66/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0054 - val_loss: 0.0354
# Epoch 67/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0050 - val_loss: 0.0351
# Epoch 68/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0048 - val_loss: 0.0350
# Epoch 69/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0056 - val_loss: 0.0363
# Epoch 70/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0053 - val_loss: 0.0351
# Epoch 71/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0050 - val_loss: 0.0361
# Epoch 72/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0051 - val_loss: 0.0346
# Epoch 73/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0055 - val_loss: 0.0386
# Epoch 74/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0055 - val_loss: 0.0397
# Epoch 75/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0069 - val_loss: 0.0345
# Epoch 76/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0050 - val_loss: 0.0342
# Epoch 77/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0050 - val_loss: 0.0366
# Epoch 78/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0056 - val_loss: 0.0345
# Epoch 79/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0048 - val_loss: 0.0373
# Epoch 80/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0051 - val_loss: 0.0345
# Epoch 81/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0055 - val_loss: 0.0360
# Epoch 82/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0047 - val_loss: 0.0347
# Epoch 83/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0046 - val_loss: 0.0346
# Epoch 84/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0047 - val_loss: 0.0362
# Epoch 85/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0052 - val_loss: 0.0348
# Epoch 86/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0049 - val_loss: 0.0350
# Epoch 87/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0055 - val_loss: 0.0339
# Epoch 88/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0047 - val_loss: 0.0340
# Epoch 89/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0060 - val_loss: 0.0372
# Epoch 90/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0068 - val_loss: 0.0339
# Epoch 91/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0050 - val_loss: 0.0340
# Epoch 92/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0046 - val_loss: 0.0341
# Epoch 93/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0045 - val_loss: 0.0344
# Epoch 94/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0046 - val_loss: 0.0344
# Epoch 95/100
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0047 - val_loss: 0.0336
# Epoch 96/100
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0045 - val_loss: 0.0346
# Epoch 97/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0044 - val_loss: 0.0340
# Epoch 98/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0044 - val_loss: 0.0352
# Epoch 99/100
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0055 - val_loss: 0.0336
# Epoch 100/100
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0053 - val_loss: 0.0341

# %%
# Make predictions
y_pred = model.predict(X_test)
# Inverse transform the predictions
y_pred = y_pred * pd.Series(stdt).values[0] + pd.Series(meant).values[0]
# Out:
# 12/12 [==============================] - 0s 10ms/step

# %%
# Make predictions
y_vpred = model.predict(X_val)
# Inverse transform the predictions
y_vpred = y_vpred * pd.Series(stdv).values[0] + pd.Series(meanv).values[0]
# Out:
# 6/6 [==============================] - 0s 3ms/step

# %%
df
# Out:
#         Price
# 0      693.28
# 1      696.76
# 2      716.02
# 3      696.85
# 4      642.17
# ...       ...
# 1822  1799.36
# 1823  1817.11
# 1824  1823.98
# 1825  1821.73
# 1826  1800.99
#
# [1827 rows x 1 columns]

# %%
train_size = int(0.7 * len(df))
test_size = int(0.2 * len(df))
val_size = len(df) - train_size - test_size

train_data = df[:train_size]
test_data = df[train_size:train_size+test_size]
val_data = df[train_size+test_size:]
# re make predictions on the testing set
x_test = np.array(test_data.index).reshape(-1, 1)
y_test = np.array(test_data['Price'])
# re make predictions on the validate set
x_val = np.array(val_data.index).reshape(-1, 1)
y_val = np.array(val_data['Price'])
train_data = df[:train_size]
test_data = df[train_size:train_size+test_size]
val_data = df[train_size+test_size:]
# calculate the RMSE
valid_rmse = np.sqrt(np.mean((y_vpred - y_val)**2))
test_rmse = np.sqrt(np.mean((y_pred - y_test)**2))
print('Validation RMSE:', valid_rmse)
print('Testing RMSE:', test_rmse)

# calculate the MAPE
valid_mape = np.mean(np.abs((y_val - y_vpred) / y_val)) * 100
test_mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100
print("Validation MAPE:", valid_mape)
print("Testing MAPE:", test_mape)

# calculate the MAE
valid_mae = np.mean(np.abs(y_vpred - y_val))
test_mae = np.mean(np.abs(y_pred - y_test))
print("Validation MAE:", valid_mae)
print("Testing MAE:", test_mae)
# Out:
# Validation RMSE: 368.70999875033255
# Testing RMSE: 1369.9085735732338
# Validation MAPE: 19.86686240713354
# Testing MAPE: 53.221432345711364
# Validation MAE: 295.91902983231284
# Testing MAE: 1091.2724922240905

# %%
# ploting the actual values and predicted values
plt.plot(train_data.index, train_data['Price'])
plt.plot(test_data.index, test_data['Price'])
plt.plot(val_data.index, val_data['Price'])
plt.plot(test_data.index[-len(y_pred):], y_pred)
plt.plot(val_data.index[-len(y_vpred):], y_vpred)
plt.legend(['Train', 'Test','Validate', 'Predictions_test','Predictions_validate'])
plt.show()
