# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense

# %%
# Read dataset file
df = pd.read_csv('BNB.csv',sep=";")
df = df[['Price']]
df = df.dropna()
df
# Out:
#        Price
# 0      15.11
# 1      14.33
# 2      14.17
# 3      14.67
# 4      13.88
# ...      ...
# 1822  312.09
# 1823  313.40
# 1824  311.30
# 1825  314.29
# 1826  309.40
#
# [1827 rows x 1 columns]

# %%
# Split the data into training, testing, and validation sets with 6:3:1
train_size = int(0.6 * len(df))
test_size = int(0.3 * len(df))
val_size = len(df) - train_size - test_size

train_data = df[:train_size]
test_data = df[train_size:train_size+test_size]
val_data = df[train_size+test_size:]

# %%
 #Normalize the data
mean = train_data.mean()
meant = test_data.mean()
meanv = val_data.mean()
std = train_data.std()
stdt = test_data.std()
stdv = val_data.std()
train_data = (train_data - mean) / std
test_data = (test_data - meant) / stdt
val_data = (val_data - meanv) / stdv

# %%
# Prepare the data for CNN
window_size = 10

def create_sequences(data, window_size):
    X = []
    y = []
    for i in range(len(data) - window_size):
        X.append(data[i:i+window_size])
        y.append(data[i+window_size])
    return np.array(X), np.array(y)

X_train, y_train = create_sequences(train_data.values, window_size)
X_test, y_test = create_sequences(test_data.values, window_size)
X_val, y_val = create_sequences(val_data.values, window_size)

# %%
# Build the CNN model
model = Sequential()
model.add(Conv1D(filters=32, kernel_size=3, activation='relu', input_shape=(window_size, 1)))
model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dense(1))

model.compile(optimizer='adam', loss='mse')

# %%
# Train the model
model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_val, y_val))
# Out:
# Epoch 1/100
# 34/34 [==============================] - 1s 8ms/step - loss: 0.2603 - val_loss: 0.3764
# Epoch 2/100
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0299 - val_loss: 0.3059
# Epoch 3/100
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0219 - val_loss: 0.3024
# Epoch 4/100
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0188 - val_loss: 0.2952
# Epoch 5/100
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0183 - val_loss: 0.2785
# Epoch 6/100
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0176 - val_loss: 0.2673
# Epoch 7/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0149 - val_loss: 0.2662
# Epoch 8/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0142 - val_loss: 0.2533
# Epoch 9/100
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0125 - val_loss: 0.2341
# Epoch 10/100
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0116 - val_loss: 0.2444
# Epoch 11/100
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0119 - val_loss: 0.2187
# Epoch 12/100
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0102 - val_loss: 0.2085
# Epoch 13/100
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0111 - val_loss: 0.2076
# Epoch 14/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0114 - val_loss: 0.2068
# Epoch 15/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0104 - val_loss: 0.1854
# Epoch 16/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0100 - val_loss: 0.2110
# Epoch 17/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0114 - val_loss: 0.1942
# Epoch 18/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0085 - val_loss: 0.1743
# Epoch 19/100
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0098 - val_loss: 0.1884
# Epoch 20/100
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0102 - val_loss: 0.1734
# Epoch 21/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0095 - val_loss: 0.1922
# Epoch 22/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0098 - val_loss: 0.1619
# Epoch 23/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0097 - val_loss: 0.1551
# Epoch 24/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0098 - val_loss: 0.1656
# Epoch 25/100
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0098 - val_loss: 0.1613
# Epoch 26/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0099 - val_loss: 0.1638
# Epoch 27/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0085 - val_loss: 0.1603
# Epoch 28/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0079 - val_loss: 0.1633
# Epoch 29/100
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0094 - val_loss: 0.1526
# Epoch 30/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0086 - val_loss: 0.1468
# Epoch 31/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0076 - val_loss: 0.1420
# Epoch 32/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0081 - val_loss: 0.1474
# Epoch 33/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0073 - val_loss: 0.1514
# Epoch 34/100
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0095 - val_loss: 0.1405
# Epoch 35/100
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0070 - val_loss: 0.1394
# Epoch 36/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0077 - val_loss: 0.1445
# Epoch 37/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0079 - val_loss: 0.1371
# Epoch 38/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0085 - val_loss: 0.1526
# Epoch 39/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0079 - val_loss: 0.1367
# Epoch 40/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0070 - val_loss: 0.1506
# Epoch 41/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0080 - val_loss: 0.1313
# Epoch 42/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0077 - val_loss: 0.1188
# Epoch 43/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0076 - val_loss: 0.1245
# Epoch 44/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0085 - val_loss: 0.1174
# Epoch 45/100
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0098 - val_loss: 0.1384
# Epoch 46/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0074 - val_loss: 0.1138
# Epoch 47/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0084 - val_loss: 0.1239
# Epoch 48/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0082 - val_loss: 0.1172
# Epoch 49/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0069 - val_loss: 0.1126
# Epoch 50/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0066 - val_loss: 0.1190
# Epoch 51/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0070 - val_loss: 0.1097
# Epoch 52/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0071 - val_loss: 0.1145
# Epoch 53/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0081 - val_loss: 0.1382
# Epoch 54/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0106 - val_loss: 0.1166
# Epoch 55/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0093 - val_loss: 0.1218
# Epoch 56/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0076 - val_loss: 0.1170
# Epoch 57/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0067 - val_loss: 0.1120
# Epoch 58/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0067 - val_loss: 0.1228
# Epoch 59/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0077 - val_loss: 0.1198
# Epoch 60/100
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0070 - val_loss: 0.1059
# Epoch 61/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0077 - val_loss: 0.1027
# Epoch 62/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0083 - val_loss: 0.1168
# Epoch 63/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0074 - val_loss: 0.1204
# Epoch 64/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0087 - val_loss: 0.1045
# Epoch 65/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0068 - val_loss: 0.1226
# Epoch 66/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0065 - val_loss: 0.1187
# Epoch 67/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0073 - val_loss: 0.1100
# Epoch 68/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0072 - val_loss: 0.1051
# Epoch 69/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0062 - val_loss: 0.1122
# Epoch 70/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0068 - val_loss: 0.1150
# Epoch 71/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0070 - val_loss: 0.1054
# Epoch 72/100
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0073 - val_loss: 0.1131
# Epoch 73/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0073 - val_loss: 0.1079
# Epoch 74/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0071 - val_loss: 0.1230
# Epoch 75/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0087 - val_loss: 0.1095
# Epoch 76/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0065 - val_loss: 0.1046
# Epoch 77/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0067 - val_loss: 0.1163
# Epoch 78/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0093 - val_loss: 0.1100
# Epoch 79/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0066 - val_loss: 0.1109
# Epoch 80/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0084 - val_loss: 0.1082
# Epoch 81/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0072 - val_loss: 0.1190
# Epoch 82/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0063 - val_loss: 0.1177
# Epoch 83/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0070 - val_loss: 0.1018
# Epoch 84/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0079 - val_loss: 0.1227
# Epoch 85/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0072 - val_loss: 0.1185
# Epoch 86/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0067 - val_loss: 0.1098
# Epoch 87/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0062 - val_loss: 0.1038
# Epoch 88/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0087 - val_loss: 0.1098
# Epoch 89/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0087 - val_loss: 0.1043
# Epoch 90/100
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0076 - val_loss: 0.1123
# Epoch 91/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0062 - val_loss: 0.1191
# Epoch 92/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0066 - val_loss: 0.1124
# Epoch 93/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0059 - val_loss: 0.1171
# Epoch 94/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0067 - val_loss: 0.1114
# Epoch 95/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0057 - val_loss: 0.1000
# Epoch 96/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0071 - val_loss: 0.1119
# Epoch 97/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0067 - val_loss: 0.1069
# Epoch 98/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0083 - val_loss: 0.1033
# Epoch 99/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0060 - val_loss: 0.0993
# Epoch 100/100
# 34/34 [==============================] - 0s 2ms/step - loss: 0.0074 - val_loss: 0.1260

# %%
# Make predictions
y_pred = model.predict(X_test)
# Inverse transform the predictions
y_pred = y_pred * pd.Series(stdt).values[0] + pd.Series(meant).values[0]
# Out:
# 17/17 [==============================] - 0s 979us/step

# %%
# Make predictions
y_vpred = model.predict(X_val)
# Inverse transform the predictions
y_vpred = y_vpred * pd.Series(stdv).values[0] + pd.Series(meanv).values[0]
# Out:
# 6/6 [==============================] - 0s 3ms/step

# %%
train_size = int(0.6 * len(df))
test_size = int(0.3 * len(df))
val_size = len(df) - train_size - test_size

train_data = df[:train_size]
test_data = df[train_size:train_size+test_size]
val_data = df[train_size+test_size:]
# re make predictions on the testing set
x_test = np.array(test_data.index).reshape(-1, 1)
y_test = np.array(test_data['Price'])
# re make predictions on the validate set
x_val = np.array(val_data.index).reshape(-1, 1)
y_val = np.array(val_data['Price'])
train_data = df[:train_size]
test_data = df[train_size:train_size+test_size]
val_data = df[train_size+test_size:]
# calculate the RMSE
valid_rmse = np.sqrt(np.mean((y_vpred - y_val)**2))
test_rmse = np.sqrt(np.mean((y_pred - y_test)**2))
print('Validation RMSE:', valid_rmse)
print('Testing RMSE:', test_rmse)

# calculate the MAPE
valid_mape = np.mean(np.abs((y_val - y_vpred) / y_val)) * 100
test_mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100
print("Validation MAPE:", valid_mape)
print("Testing MAPE:", test_mape)

# calculate the MAE
valid_mae = np.mean(np.abs(y_vpred - y_val))
test_mae = np.mean(np.abs(y_pred - y_test))
print("Validation MAE:", valid_mae)
print("Testing MAPE:", test_mape)
# Out:
# Validation RMSE: 38.95117927071067
# Testing RMSE: 153.58092095575037
# Validation MAPE: 10.585318691482911
# Testing MAPE: 33.97801891306062
# Validation MAE: 30.567578088890563
# Testing MAPE: 33.97801891306062

# %%
# ploting the actual values and predicted values
plt.plot(test_data.index, test_data['Price'])
plt.plot(val_data.index, val_data['Price'])
plt.plot(test_data.index[-len(y_pred):], y_pred)
plt.plot(val_data.index[-len(y_vpred):], y_vpred)
plt.legend(['Test','Validate', 'Predictions_test','Predictions_validate'])
plt.show()
