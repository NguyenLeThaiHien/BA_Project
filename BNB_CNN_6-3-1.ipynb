# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense

# %%
# Read dataset file
df = pd.read_csv('BNB.csv',sep=";")
df = df[['Price']]
df = df.dropna()
df
# Out:
#        Price
# 0      15.11
# 1      14.33
# 2      14.17
# 3      14.67
# 4      13.88
# ...      ...
# 1822  312.09
# 1823  313.40
# 1824  311.30
# 1825  314.29
# 1826  309.40
#
# [1827 rows x 1 columns]

# %%
# Split the data into training, testing, and validation sets with 6:3:1
train_size = int(0.6 * len(df))
test_size = int(0.3 * len(df))
val_size = len(df) - train_size - test_size

train_data = df[:train_size]
test_data = df[train_size:train_size+test_size]
val_data = df[train_size+test_size:]

# %%
 #Normalize the data
mean = train_data.mean()
meant = test_data.mean()
meanv = val_data.mean()
std = train_data.std()
stdt = test_data.std()
stdv = val_data.std()
train_data = (train_data - mean) / std
test_data = (test_data - meant) / stdt
val_data = (val_data - meanv) / stdv

# %%
# Prepare the data for CNN
window_size = 10

def create_sequences(data, window_size):
    X = []
    y = []
    for i in range(len(data) - window_size):
        X.append(data[i:i+window_size])
        y.append(data[i+window_size])
    return np.array(X), np.array(y)

X_train, y_train = create_sequences(train_data.values, window_size)
X_test, y_test = create_sequences(test_data.values, window_size)
X_val, y_val = create_sequences(val_data.values, window_size)

# %%
# Build the CNN model
model = Sequential()
model.add(Conv1D(filters=32, kernel_size=3, activation='relu', input_shape=(window_size, 1)))
model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dense(1))

model.compile(optimizer='adam', loss='mse')

# %%
# Train the model
model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_val, y_val))
# Out:
# Epoch 1/100
# 34/34 [==============================] - 2s 13ms/step - loss: 0.2241 - val_loss: 0.3147
# Epoch 2/100
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0176 - val_loss: 0.2903
# Epoch 3/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0171 - val_loss: 0.2730
# Epoch 4/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0147 - val_loss: 0.2442
# Epoch 5/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0146 - val_loss: 0.2590
# Epoch 6/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0139 - val_loss: 0.2392
# Epoch 7/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0124 - val_loss: 0.2346
# Epoch 8/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0110 - val_loss: 0.2286
# Epoch 9/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0108 - val_loss: 0.2401
# Epoch 10/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0111 - val_loss: 0.2146
# Epoch 11/100
# 34/34 [==============================] - 0s 6ms/step - loss: 0.0133 - val_loss: 0.2193
# Epoch 12/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0108 - val_loss: 0.1992
# Epoch 13/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0100 - val_loss: 0.1971
# Epoch 14/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0111 - val_loss: 0.2040
# Epoch 15/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0098 - val_loss: 0.2076
# Epoch 16/100
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0107 - val_loss: 0.1888
# Epoch 17/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0091 - val_loss: 0.1781
# Epoch 18/100
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0096 - val_loss: 0.1990
# Epoch 19/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0093 - val_loss: 0.1642
# Epoch 20/100
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0084 - val_loss: 0.1942
# Epoch 21/100
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0149 - val_loss: 0.1698
# Epoch 22/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0087 - val_loss: 0.1781
# Epoch 23/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0083 - val_loss: 0.1615
# Epoch 24/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0088 - val_loss: 0.1802
# Epoch 25/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0082 - val_loss: 0.1478
# Epoch 26/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0118 - val_loss: 0.1566
# Epoch 27/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0103 - val_loss: 0.1493
# Epoch 28/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0094 - val_loss: 0.1773
# Epoch 29/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0109 - val_loss: 0.1491
# Epoch 30/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0095 - val_loss: 0.1668
# Epoch 31/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0080 - val_loss: 0.1533
# Epoch 32/100
# 34/34 [==============================] - 0s 6ms/step - loss: 0.0091 - val_loss: 0.1405
# Epoch 33/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0082 - val_loss: 0.1551
# Epoch 34/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0076 - val_loss: 0.1391
# Epoch 35/100
# 34/34 [==============================] - 0s 7ms/step - loss: 0.0084 - val_loss: 0.1409
# Epoch 36/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0080 - val_loss: 0.1499
# Epoch 37/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0074 - val_loss: 0.1517
# Epoch 38/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0089 - val_loss: 0.1441
# Epoch 39/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0093 - val_loss: 0.1331
# Epoch 40/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0127 - val_loss: 0.1497
# Epoch 41/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0087 - val_loss: 0.1500
# Epoch 42/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0101 - val_loss: 0.1452
# Epoch 43/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0076 - val_loss: 0.1420
# Epoch 44/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0087 - val_loss: 0.1555
# Epoch 45/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0095 - val_loss: 0.1478
# Epoch 46/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0123 - val_loss: 0.1315
# Epoch 47/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0076 - val_loss: 0.1472
# Epoch 48/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0082 - val_loss: 0.1383
# Epoch 49/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0075 - val_loss: 0.1446
# Epoch 50/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0085 - val_loss: 0.1475
# Epoch 51/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0073 - val_loss: 0.1485
# Epoch 52/100
# 34/34 [==============================] - 0s 6ms/step - loss: 0.0072 - val_loss: 0.1438
# Epoch 53/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0073 - val_loss: 0.1418
# Epoch 54/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0074 - val_loss: 0.1357
# Epoch 55/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0076 - val_loss: 0.1351
# Epoch 56/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0101 - val_loss: 0.1582
# Epoch 57/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0112 - val_loss: 0.1299
# Epoch 58/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0082 - val_loss: 0.1492
# Epoch 59/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0082 - val_loss: 0.1312
# Epoch 60/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0079 - val_loss: 0.1318
# Epoch 61/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0077 - val_loss: 0.1345
# Epoch 62/100
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0085 - val_loss: 0.1469
# Epoch 63/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0094 - val_loss: 0.1393
# Epoch 64/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0076 - val_loss: 0.1317
# Epoch 65/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0076 - val_loss: 0.1375
# Epoch 66/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0077 - val_loss: 0.1307
# Epoch 67/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0073 - val_loss: 0.1263
# Epoch 68/100
# 34/34 [==============================] - 0s 3ms/step - loss: 0.0080 - val_loss: 0.1383
# Epoch 69/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0069 - val_loss: 0.1463
# Epoch 70/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0073 - val_loss: 0.1303
# Epoch 71/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0095 - val_loss: 0.1399
# Epoch 72/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0078 - val_loss: 0.1299
# Epoch 73/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0074 - val_loss: 0.1397
# Epoch 74/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0094 - val_loss: 0.1774
# Epoch 75/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0135 - val_loss: 0.1159
# Epoch 76/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0090 - val_loss: 0.1359
# Epoch 77/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0103 - val_loss: 0.1200
# Epoch 78/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0108 - val_loss: 0.1355
# Epoch 79/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0076 - val_loss: 0.1298
# Epoch 80/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0069 - val_loss: 0.1303
# Epoch 81/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0067 - val_loss: 0.1272
# Epoch 82/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0076 - val_loss: 0.1279
# Epoch 83/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0086 - val_loss: 0.1240
# Epoch 84/100
# 34/34 [==============================] - 0s 6ms/step - loss: 0.0075 - val_loss: 0.1261
# Epoch 85/100
# 34/34 [==============================] - 0s 6ms/step - loss: 0.0069 - val_loss: 0.1349
# Epoch 86/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0071 - val_loss: 0.1262
# Epoch 87/100
# 34/34 [==============================] - 0s 6ms/step - loss: 0.0070 - val_loss: 0.1301
# Epoch 88/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0073 - val_loss: 0.1286
# Epoch 89/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0083 - val_loss: 0.1375
# Epoch 90/100
# 34/34 [==============================] - 0s 6ms/step - loss: 0.0092 - val_loss: 0.1417
# Epoch 91/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0098 - val_loss: 0.1367
# Epoch 92/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0068 - val_loss: 0.1268
# Epoch 93/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0101 - val_loss: 0.1328
# Epoch 94/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0094 - val_loss: 0.1457
# Epoch 95/100
# 34/34 [==============================] - 0s 6ms/step - loss: 0.0102 - val_loss: 0.1276
# Epoch 96/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0075 - val_loss: 0.1267
# Epoch 97/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0088 - val_loss: 0.1176
# Epoch 98/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0087 - val_loss: 0.1360
# Epoch 99/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0068 - val_loss: 0.1305
# Epoch 100/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0077 - val_loss: 0.1285

# %%
# Make predictions
y_pred = model.predict(X_test)
# Inverse transform the predictions
y_pred = y_pred * pd.Series(stdt).values[0] + pd.Series(meant).values[0]
# Out:
# 17/17 [==============================] - 0s 2ms/step

# %%
# Make predictions
y_vpred = model.predict(X_val)
# Inverse transform the predictions
y_vpred = y_vpred * pd.Series(stdv).values[0] + pd.Series(meanv).values[0]
# Out:
# 6/6 [==============================] - 0s 3ms/step

# %%
train_size = int(0.6 * len(df))
test_size = int(0.3 * len(df))
val_size = len(df) - train_size - test_size

train_data = df[:train_size]
test_data = df[train_size:train_size+test_size]
val_data = df[train_size+test_size:]
# re make predictions on the testing set
x_test = np.array(test_data.index).reshape(-1, 1)
y_test = np.array(test_data['Price'])
# re make predictions on the validate set
x_val = np.array(val_data.index).reshape(-1, 1)
y_val = np.array(val_data['Price'])
train_data = df[:train_size]
test_data = df[train_size:train_size+test_size]
val_data = df[train_size+test_size:]
# calculate the RMSE
valid_rmse = np.sqrt(np.mean((y_vpred - y_val)**2))
test_rmse = np.sqrt(np.mean((y_pred - y_test)**2))
print('Validation RMSE:', valid_rmse)
print('Testing RMSE:', test_rmse)

# calculate the MAPE
valid_mape = np.mean(np.abs((y_val - y_vpred) / y_val)) * 100
test_mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100
print("Validation MAPE:", valid_mape)
print("Testing MAPE:", test_mape)

# calculate the MAE
valid_mae = np.mean(np.abs(y_vpred - y_val))
test_mae = np.mean(np.abs(y_pred - y_test))
print("Validation MAE:", valid_mae)
print("Testing MAE:", test_mae)
# Out:
# Validation RMSE: 37.669551060076316
# Testing RMSE: 149.71230010604768
# Validation MAPE: 10.23680978874054
# Testing MAPE: 33.21530317313805
# Validation MAE: 29.47724948452775
# Testing MAE: 118.39499422988975

# %%
# ploting the actual values and predicted values
plt.plot(test_data.index, test_data['Price'])
plt.plot(val_data.index, val_data['Price'])
plt.plot(test_data.index[-len(y_pred):], y_pred)
plt.plot(val_data.index[-len(y_vpred):], y_vpred)
plt.legend(['Test','Validate', 'Predictions_test','Predictions_validate'])
plt.show()
