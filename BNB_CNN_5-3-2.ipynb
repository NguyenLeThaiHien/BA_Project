# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense

# %%
# Read dataset file
df = pd.read_csv('BNB.csv',sep=";")
df = df[['Price']]
df = df.dropna()
df
# Out:
#        Price
# 0      15.11
# 1      14.33
# 2      14.17
# 3      14.67
# 4      13.88
# ...      ...
# 1822  312.09
# 1823  313.40
# 1824  311.30
# 1825  314.29
# 1826  309.40
#
# [1827 rows x 1 columns]

# %%
# Split the data into training, testing, and validation sets with 5:3:2
train_size = int(0.5 * len(df))
test_size = int(0.3 * len(df))
val_size = len(df) - train_size - test_size

train_data = df[:train_size]
test_data = df[train_size:train_size+test_size]
val_data = df[train_size+test_size:]

# %%
 #Normalize the data
mean = train_data.mean()
meant = test_data.mean()
meanv = val_data.mean()
std = train_data.std()
stdt = test_data.std()
stdv = val_data.std()
train_data = (train_data - mean) / std
test_data = (test_data - meant) / stdt
val_data = (val_data - meanv) / stdv

# %%
# Prepare the data for CNN
window_size = 10

def create_sequences(data, window_size):
    X = []
    y = []
    for i in range(len(data) - window_size):
        X.append(data[i:i+window_size])
        y.append(data[i+window_size])
    return np.array(X), np.array(y)

X_train, y_train = create_sequences(train_data.values, window_size)
X_test, y_test = create_sequences(test_data.values, window_size)
X_val, y_val = create_sequences(val_data.values, window_size)

# %%
# Build the CNN model
model = Sequential()
model.add(Conv1D(filters=32, kernel_size=3, activation='relu', input_shape=(window_size, 1)))
model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dense(1))

model.compile(optimizer='adam', loss='mse')

# %%
# Train the model
model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_val, y_val))
# Out:
# Epoch 1/100
# 29/29 [==============================] - 1s 8ms/step - loss: 0.2504 - val_loss: 0.3295
# Epoch 2/100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0456 - val_loss: 0.2251
# Epoch 3/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0323 - val_loss: 0.1622
# Epoch 4/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0250 - val_loss: 0.1483
# Epoch 5/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0208 - val_loss: 0.1265
# Epoch 6/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0190 - val_loss: 0.1214
# Epoch 7/100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0173 - val_loss: 0.1204
# Epoch 8/100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0182 - val_loss: 0.1132
# Epoch 9/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0154 - val_loss: 0.1128
# Epoch 10/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0154 - val_loss: 0.1112
# Epoch 11/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0156 - val_loss: 0.1125
# Epoch 12/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0150 - val_loss: 0.1127
# Epoch 13/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0148 - val_loss: 0.1062
# Epoch 14/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0151 - val_loss: 0.1123
# Epoch 15/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0148 - val_loss: 0.1069
# Epoch 16/100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0150 - val_loss: 0.1165
# Epoch 17/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0155 - val_loss: 0.1122
# Epoch 18/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0147 - val_loss: 0.1099
# Epoch 19/100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0141 - val_loss: 0.1080
# Epoch 20/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0144 - val_loss: 0.1104
# Epoch 21/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0139 - val_loss: 0.1116
# Epoch 22/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0142 - val_loss: 0.1097
# Epoch 23/100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0142 - val_loss: 0.1057
# Epoch 24/100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0139 - val_loss: 0.1083
# Epoch 25/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0139 - val_loss: 0.1071
# Epoch 26/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0148 - val_loss: 0.1058
# Epoch 27/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0137 - val_loss: 0.1124
# Epoch 28/100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0140 - val_loss: 0.1076
# Epoch 29/100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0135 - val_loss: 0.1206
# Epoch 30/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0163 - val_loss: 0.1164
# Epoch 31/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0140 - val_loss: 0.1124
# Epoch 32/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0131 - val_loss: 0.1085
# Epoch 33/100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0148 - val_loss: 0.1079
# Epoch 34/100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0130 - val_loss: 0.1118
# Epoch 35/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0132 - val_loss: 0.1117
# Epoch 36/100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0129 - val_loss: 0.1095
# Epoch 37/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0132 - val_loss: 0.1134
# Epoch 38/100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0129 - val_loss: 0.1083
# Epoch 39/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0148 - val_loss: 0.1089
# Epoch 40/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0144 - val_loss: 0.1149
# Epoch 41/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0128 - val_loss: 0.1072
# Epoch 42/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0146 - val_loss: 0.1061
# Epoch 43/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0157 - val_loss: 0.1059
# Epoch 44/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0149 - val_loss: 0.1099
# Epoch 45/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0131 - val_loss: 0.1135
# Epoch 46/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0155 - val_loss: 0.1143
# Epoch 47/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0140 - val_loss: 0.1131
# Epoch 48/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0133 - val_loss: 0.1131
# Epoch 49/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0138 - val_loss: 0.1115
# Epoch 50/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0125 - val_loss: 0.1083
# Epoch 51/100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0126 - val_loss: 0.1132
# Epoch 52/100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0129 - val_loss: 0.1085
# Epoch 53/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0126 - val_loss: 0.1120
# Epoch 54/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0125 - val_loss: 0.1100
# Epoch 55/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0124 - val_loss: 0.1181
# Epoch 56/100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0129 - val_loss: 0.1148
# Epoch 57/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0122 - val_loss: 0.1157
# Epoch 58/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0125 - val_loss: 0.1079
# Epoch 59/100
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0139 - val_loss: 0.1092
# Epoch 60/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0124 - val_loss: 0.1157
# Epoch 61/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0127 - val_loss: 0.1195
# Epoch 62/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0132 - val_loss: 0.1124
# Epoch 63/100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0119 - val_loss: 0.1119
# Epoch 64/100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0122 - val_loss: 0.1069
# Epoch 65/100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0123 - val_loss: 0.1200
# Epoch 66/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0141 - val_loss: 0.1142
# Epoch 67/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0128 - val_loss: 0.1070
# Epoch 68/100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0132 - val_loss: 0.1086
# Epoch 69/100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0145 - val_loss: 0.1092
# Epoch 70/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0135 - val_loss: 0.1114
# Epoch 71/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0124 - val_loss: 0.1132
# Epoch 72/100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0119 - val_loss: 0.1117
# Epoch 73/100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0120 - val_loss: 0.1094
# Epoch 74/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0130 - val_loss: 0.1140
# Epoch 75/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0127 - val_loss: 0.1142
# Epoch 76/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0119 - val_loss: 0.1085
# Epoch 77/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0120 - val_loss: 0.1148
# Epoch 78/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0121 - val_loss: 0.1090
# Epoch 79/100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0120 - val_loss: 0.1144
# Epoch 80/100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0119 - val_loss: 0.1103
# Epoch 81/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0122 - val_loss: 0.1148
# Epoch 82/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0133 - val_loss: 0.1086
# Epoch 83/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0123 - val_loss: 0.1217
# Epoch 84/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0128 - val_loss: 0.1110
# Epoch 85/100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0125 - val_loss: 0.1153
# Epoch 86/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0124 - val_loss: 0.1084
# Epoch 87/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0120 - val_loss: 0.1113
# Epoch 88/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0118 - val_loss: 0.1121
# Epoch 89/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0116 - val_loss: 0.1183
# Epoch 90/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0127 - val_loss: 0.1169
# Epoch 91/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0134 - val_loss: 0.1116
# Epoch 92/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0119 - val_loss: 0.1148
# Epoch 93/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0120 - val_loss: 0.1150
# Epoch 94/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0117 - val_loss: 0.1117
# Epoch 95/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0114 - val_loss: 0.1105
# Epoch 96/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0114 - val_loss: 0.1162
# Epoch 97/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0129 - val_loss: 0.1139
# Epoch 98/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0118 - val_loss: 0.1085
# Epoch 99/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0155 - val_loss: 0.1106
# Epoch 100/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0124 - val_loss: 0.1170

# %%
# Make predictions
y_pred = model.predict(X_test)
# Inverse transform the predictions
y_pred = y_pred * pd.Series(stdt).values[0] + pd.Series(meant).values[0]
# Out:
# 17/17 [==============================] - 0s 2ms/step

# %%
# Make predictions
y_vpred = model.predict(X_val)
# Inverse transform the predictions
y_vpred = y_vpred * pd.Series(stdv).values[0] + pd.Series(meanv).values[0]
# Out:
# 12/12 [==============================] - 0s 0s/step

# %%
train_size = int(0.5 * len(df))
test_size = int(0.3 * len(df))
val_size = len(df) - train_size - test_size

train_data = df[:train_size]
test_data = df[train_size:train_size+test_size]
val_data = df[train_size+test_size:]
# re make predictions on the testing set
x_test = np.array(test_data.index).reshape(-1, 1)
y_test = np.array(test_data['Price'])
# re make predictions on the validate set
x_val = np.array(val_data.index).reshape(-1, 1)
y_val = np.array(val_data['Price'])
train_data = df[:train_size]
test_data = df[train_size:train_size+test_size]
val_data = df[train_size+test_size:]
# calculate the RMSE
valid_rmse = np.sqrt(np.mean((y_vpred - y_val)**2))
test_rmse = np.sqrt(np.mean((y_pred - y_test)**2))
print('Validation RMSE:', valid_rmse)
print('Testing RMSE:', test_rmse)

# calculate the MAPE
valid_mape = np.mean(np.abs((y_val - y_vpred) / y_val)) * 100
test_mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100
print("Validation MAPE:", valid_mape)
print("Testing MAPE:", test_mape)

# calculate the MAE
valid_mae = np.mean(np.abs(y_vpred - y_val))
test_mae = np.mean(np.abs(y_pred - y_test))
print("Validation MAE:", valid_mae)
print("Testing MAPE:", test_mape)
# Out:
# Validation RMSE: 43.75915981336188
# Testing RMSE: 237.9260275987486
# Validation MAPE: 12.550997522147034
# Testing MAPE: 180.04851005926426
# Validation MAE: 34.96483108138265
# Testing MAPE: 180.04851005926426

# %%
# ploting the actual values and predicted values
plt.plot(test_data.index, test_data['Price'])
plt.plot(val_data.index, val_data['Price'])
plt.plot(test_data.index[-len(y_pred):], y_pred)
plt.plot(val_data.index[-len(y_vpred):], y_vpred)
plt.legend(['Test','Validate', 'Predictions_test','Predictions_validate'])
plt.show()
