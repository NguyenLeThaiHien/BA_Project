# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense

# %%
# Read dataset file
df = pd.read_csv('/content/drive/MyDrive/PTKD/ETH.csv')
df = df[['Price']]
df = df.dropna()
df
# Out:
#         Price
# 0      693.28
# 1      696.76
# 2      716.02
# 3      696.85
# 4      642.17
# ...       ...
# 1822  1799.36
# 1823  1817.11
# 1824  1823.98
# 1825  1821.73
# 1826  1800.99
#
# [1827 rows x 1 columns]

# %%
# Split the data into training, testing, and validation sets
train_size = int(0.6 * len(df))
test_size = int(0.3 * len(df))
val_size = len(df) - train_size - test_size

train_data = df[:train_size]
test_data = df[train_size:train_size+test_size]
val_data = df[train_size+test_size:]

# %%
# Normalize the data
mean = train_data.mean()
meant = test_data.mean()
meanv = val_data.mean()
std = train_data.std()
stdt = test_data.std()
stdv = val_data.std()
train_data = (train_data - mean) / std
test_data = (test_data - meant) / stdt
val_data = (val_data - meanv) / stdv

# %%
# Prepare the data for CNN
window_size = 10

def create_sequences(data, window_size):
    X = []
    y = []
    for i in range(len(data) - window_size):
        X.append(data[i:i+window_size])
        y.append(data[i+window_size])
    return np.array(X), np.array(y)

X_train, y_train = create_sequences(train_data.values, window_size)
X_test, y_test = create_sequences(test_data.values, window_size)
X_val, y_val = create_sequences(val_data.values, window_size)

# %%
# Build the CNN model
model = Sequential()
model.add(Conv1D(filters=32, kernel_size=3, activation='relu', input_shape=(window_size, 1)))
model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dense(1))

model.compile(optimizer='adam', loss='mse')

# %%
# Train the model
model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_val, y_val))
# Out:
# Epoch 1/100
# 34/34 [==============================] - 11s 22ms/step - loss: 0.4529 - val_loss: 0.1156
# Epoch 2/100
# 34/34 [==============================] - 0s 7ms/step - loss: 0.0206 - val_loss: 0.1107
# Epoch 3/100
# 34/34 [==============================] - 0s 6ms/step - loss: 0.0185 - val_loss: 0.0917
# Epoch 4/100
# 34/34 [==============================] - 0s 6ms/step - loss: 0.0165 - val_loss: 0.0843
# Epoch 5/100
# 34/34 [==============================] - 0s 6ms/step - loss: 0.0136 - val_loss: 0.0773
# Epoch 6/100
# 34/34 [==============================] - 0s 6ms/step - loss: 0.0132 - val_loss: 0.0754
# Epoch 7/100
# 34/34 [==============================] - 0s 8ms/step - loss: 0.0135 - val_loss: 0.0733
# Epoch 8/100
# 34/34 [==============================] - 0s 10ms/step - loss: 0.0124 - val_loss: 0.0679
# Epoch 9/100
# 34/34 [==============================] - 0s 12ms/step - loss: 0.0106 - val_loss: 0.0710
# Epoch 10/100
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0097 - val_loss: 0.0635
# Epoch 11/100
# 34/34 [==============================] - 0s 9ms/step - loss: 0.0090 - val_loss: 0.0700
# Epoch 12/100
# 34/34 [==============================] - 0s 7ms/step - loss: 0.0088 - val_loss: 0.0551
# Epoch 13/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0116 - val_loss: 0.0558
# Epoch 14/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0138 - val_loss: 0.0606
# Epoch 15/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0087 - val_loss: 0.0509
# Epoch 16/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0094 - val_loss: 0.0494
# Epoch 17/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0075 - val_loss: 0.0478
# Epoch 18/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0105 - val_loss: 0.0465
# Epoch 19/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0072 - val_loss: 0.0461
# Epoch 20/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0093 - val_loss: 0.0475
# Epoch 21/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0068 - val_loss: 0.0437
# Epoch 22/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0073 - val_loss: 0.0452
# Epoch 23/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0077 - val_loss: 0.0560
# Epoch 24/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0067 - val_loss: 0.0455
# Epoch 25/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0075 - val_loss: 0.0541
# Epoch 26/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0074 - val_loss: 0.0434
# Epoch 27/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0078 - val_loss: 0.0477
# Epoch 28/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0073 - val_loss: 0.0522
# Epoch 29/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0075 - val_loss: 0.0456
# Epoch 30/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0058 - val_loss: 0.0455
# Epoch 31/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0065 - val_loss: 0.0435
# Epoch 32/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0059 - val_loss: 0.0436
# Epoch 33/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0057 - val_loss: 0.0439
# Epoch 34/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0082 - val_loss: 0.0499
# Epoch 35/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0065 - val_loss: 0.0421
# Epoch 36/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0056 - val_loss: 0.0426
# Epoch 37/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0053 - val_loss: 0.0428
# Epoch 38/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0052 - val_loss: 0.0422
# Epoch 39/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0075 - val_loss: 0.0450
# Epoch 40/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0053 - val_loss: 0.0430
# Epoch 41/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0064 - val_loss: 0.0442
# Epoch 42/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0062 - val_loss: 0.0458
# Epoch 43/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0064 - val_loss: 0.0462
# Epoch 44/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0053 - val_loss: 0.0416
# Epoch 45/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0067 - val_loss: 0.0521
# Epoch 46/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0072 - val_loss: 0.0418
# Epoch 47/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0055 - val_loss: 0.0429
# Epoch 48/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0053 - val_loss: 0.0418
# Epoch 49/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0059 - val_loss: 0.0409
# Epoch 50/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0068 - val_loss: 0.0418
# Epoch 51/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0066 - val_loss: 0.0422
# Epoch 52/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0060 - val_loss: 0.0457
# Epoch 53/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0062 - val_loss: 0.0418
# Epoch 54/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0050 - val_loss: 0.0394
# Epoch 55/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0059 - val_loss: 0.0424
# Epoch 56/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0053 - val_loss: 0.0400
# Epoch 57/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0065 - val_loss: 0.0395
# Epoch 58/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0068 - val_loss: 0.0399
# Epoch 59/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0053 - val_loss: 0.0431
# Epoch 60/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0057 - val_loss: 0.0404
# Epoch 61/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0051 - val_loss: 0.0405
# Epoch 62/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0063 - val_loss: 0.0397
# Epoch 63/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0079 - val_loss: 0.0396
# Epoch 64/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0073 - val_loss: 0.0397
# Epoch 65/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0057 - val_loss: 0.0416
# Epoch 66/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0052 - val_loss: 0.0408
# Epoch 67/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0056 - val_loss: 0.0448
# Epoch 68/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0054 - val_loss: 0.0506
# Epoch 69/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0065 - val_loss: 0.0407
# Epoch 70/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0073 - val_loss: 0.0394
# Epoch 71/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0066 - val_loss: 0.0409
# Epoch 72/100
# 34/34 [==============================] - 0s 7ms/step - loss: 0.0060 - val_loss: 0.0388
# Epoch 73/100
# 34/34 [==============================] - 0s 7ms/step - loss: 0.0053 - val_loss: 0.0390
# Epoch 74/100
# 34/34 [==============================] - 0s 7ms/step - loss: 0.0071 - val_loss: 0.0405
# Epoch 75/100
# 34/34 [==============================] - 0s 7ms/step - loss: 0.0052 - val_loss: 0.0416
# Epoch 76/100
# 34/34 [==============================] - 0s 7ms/step - loss: 0.0050 - val_loss: 0.0391
# Epoch 77/100
# 34/34 [==============================] - 0s 6ms/step - loss: 0.0055 - val_loss: 0.0476
# Epoch 78/100
# 34/34 [==============================] - 0s 6ms/step - loss: 0.0050 - val_loss: 0.0470
# Epoch 79/100
# 34/34 [==============================] - 0s 8ms/step - loss: 0.0061 - val_loss: 0.0381
# Epoch 80/100
# 34/34 [==============================] - 0s 6ms/step - loss: 0.0066 - val_loss: 0.0389
# Epoch 81/100
# 34/34 [==============================] - 0s 6ms/step - loss: 0.0058 - val_loss: 0.0393
# Epoch 82/100
# 34/34 [==============================] - 0s 7ms/step - loss: 0.0053 - val_loss: 0.0434
# Epoch 83/100
# 34/34 [==============================] - 0s 6ms/step - loss: 0.0069 - val_loss: 0.0373
# Epoch 84/100
# 34/34 [==============================] - 0s 6ms/step - loss: 0.0057 - val_loss: 0.0406
# Epoch 85/100
# 34/34 [==============================] - 0s 6ms/step - loss: 0.0047 - val_loss: 0.0383
# Epoch 86/100
# 34/34 [==============================] - 0s 6ms/step - loss: 0.0060 - val_loss: 0.0386
# Epoch 87/100
# 34/34 [==============================] - 0s 6ms/step - loss: 0.0046 - val_loss: 0.0393
# Epoch 88/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0047 - val_loss: 0.0382
# Epoch 89/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0047 - val_loss: 0.0382
# Epoch 90/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0057 - val_loss: 0.0390
# Epoch 91/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0051 - val_loss: 0.0398
# Epoch 92/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0056 - val_loss: 0.0380
# Epoch 93/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0051 - val_loss: 0.0388
# Epoch 94/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0072 - val_loss: 0.0391
# Epoch 95/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0063 - val_loss: 0.0392
# Epoch 96/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0056 - val_loss: 0.0375
# Epoch 97/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0050 - val_loss: 0.0390
# Epoch 98/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0058 - val_loss: 0.0402
# Epoch 99/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0059 - val_loss: 0.0377
# Epoch 100/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0122 - val_loss: 0.0513

# %%
# Make predictions
y_pred = model.predict(X_test)
# Inverse transform the predictions
y_pred = y_pred * pd.Series(stdt).values[0] + pd.Series(meant).values[0]
# Out:
# 17/17 [==============================] - 0s 3ms/step

# %%
# Make predictions
y_vpred = model.predict(X_val)
# Inverse transform the predictions
y_vpred = y_vpred * pd.Series(stdv).values[0] + pd.Series(meanv).values[0]
# Out:
# 6/6 [==============================] - 0s 2ms/step

# %%
df
# Out:
#         Price
# 0      693.28
# 1      696.76
# 2      716.02
# 3      696.85
# 4      642.17
# ...       ...
# 1822  1799.36
# 1823  1817.11
# 1824  1823.98
# 1825  1821.73
# 1826  1800.99
#
# [1827 rows x 1 columns]

# %%
train_size = int(0.6 * len(df))
test_size = int(0.3 * len(df))
val_size = len(df) - train_size - test_size

train_data = df[:train_size]
test_data = df[train_size:train_size+test_size]
val_data = df[train_size+test_size:]
# re make predictions on the testing set
x_test = np.array(test_data.index).reshape(-1, 1)
y_test = np.array(test_data['Price'])
# re make predictions on the validate set
x_val = np.array(val_data.index).reshape(-1, 1)
y_val = np.array(val_data['Price'])
train_data = df[:train_size]
test_data = df[train_size:train_size+test_size]
val_data = df[train_size+test_size:]
# calculate the RMSE
valid_rmse = np.sqrt(np.mean((y_vpred - y_val)**2))
test_rmse = np.sqrt(np.mean((y_pred - y_test)**2))
print('Validation RMSE:', valid_rmse)
print('Testing RMSE:', test_rmse)

# calculate the MAPE
valid_mape = np.mean(np.abs((y_val - y_vpred) / y_val)) * 100
test_mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100
print("Validation MAPE:", valid_mape)
print("Testing MAPE:", test_mape)

# calculate the MAE
valid_mae = np.mean(np.abs(y_vpred - y_val))
test_mae = np.mean(np.abs(y_pred - y_test))
print("Validation MAE:", valid_mae)
print("Testing MAE:", test_mae)
# Out:
# Validation RMSE: 382.7934205301904
# Testing RMSE: 1464.3054693133565
# Validation MAPE: 20.666976546909012
# Testing MAPE: 54.68657736748581
# Validation MAE: 309.02496142425434
# Testing MAE: 1185.8032946110898

# %%
# ploting the actual values and predicted values
plt.plot(train_data.index, train_data['Price'])
plt.plot(test_data.index, test_data['Price'])
plt.plot(val_data.index, val_data['Price'])
plt.plot(test_data.index[-len(y_pred):], y_pred)
plt.plot(val_data.index[-len(y_vpred):], y_vpred)
plt.legend(['Train', 'Test','Validate', 'Predictions_test','Predictions_validate'])
plt.show()
